# %%
import pandas as pd

# %%
# Carregando o arquivo que você salvou anteriormente
df = pd.read_parquet("/workspaces/Remodelacao_mestrado/data/merra2/aod550_merra.parquet")

# Verificando se as datas e coordenadas foram preservadas corretamente
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10799712 entries, 0 to 10799711
# Data columns (total 5 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   time       datetime64[ns]
#  1   lat        float64
#  2   lon        float64
#  3   TOTEXTTAU  float32
#  4   TOTSCATAU  float32
# dtypes: datetime64[ns](1), float32(2), float64(2)
# memory usage: 329.6 MB
# None
#                  time   lat     lon  TOTEXTTAU  TOTSCATAU
# 0 2015-01-01 00:30:00 -25.0 -52.500   0.131541   0.123313
# 1 2015-01-01 00:30:00 -25.0 -51.875   0.154063   0.147056
# 2 2015-01-01 00:30:00 -25.0 -51.250   0.145824   0.139610
# 3 2015-01-01 00:30:00 -25.0 -50.625   0.118144   0.112937
# 4 2015-01-01 00:30:00 -25.0 -50.000   0.113322   0.108756
